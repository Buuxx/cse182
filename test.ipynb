# %%
import matplotlib.pyplot as plt
num = [1,10,2,7,13]
weight = [1,90,1,1,1]
fig, ax = plt.subplots()
ax.hist(num, 5, weights=weight)
# Out:
# (array([ 2.,  0.,  1., 90.,  1.]),
#  array([ 1. ,  3.4,  5.8,  8.2, 10.6, 13. ]),
#  <BarContainer object of 5 artists>)
